# %% [markdown]
# <h1 style="font-size:3rem;color:orange">Привіт Наш Юпітер :)</h1>

# %% [markdown]
# # Підлкючення фото

# %% [markdown]
# <img src="https://mitsloan.mit.edu/sites/default/files/styles/og_image/public/2026-02/agentic-ai-dobi.jpg.webp?h=7691f918&itok=Eer2U5KD"/>

# %% [markdown]
# ## Simple code

# %%
print("Суди взазить Пайтон")
# Out:
# Суди взазить Пайтон

# %%
person = input("Як Вас звати?")
message = "Привіт, {}!".format(person)
print(message)
# Out:
# Як Вас звати? Вова
# Привіт, Вова!

# %%
story = """Ще не вмерла Україна
Ні слва ні воля
"""
print(story)
print(len(story))
# Out:
# Ще не вмерла Україна
# Ні слва ні воля
#
# 37

# %%
x = 12
y = 8
z=(x*3)/y
m=(x*3)%y
print(z)
print(m)
# Out:
# 4.5
# 4

# %%
friends = ['Іван', 'Семен', 'Віктор']
print(friends[1])
# Out:
# Семен

# %% [markdown]
# # Має бути прикольний Markdown

# %%
from IPython.display import display, Markdown
display(Markdown("""
<h1>Привіт!</h1>
"""
))
# Out:
# <h1>Привіт!</h1>
